# %%
  # !wget https://openslr.trmal.net/resources/52/asr_sinhala_0.zip
# Out:
# --2026-07-15 10:32:47--  https://openslr.trmal.net/resources/52/asr_sinhala_0.zip
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 915237858 (873M) [application/zip]
# Saving to: ‘asr_sinhala_0.zip’
#
# asr_sinhala_0.zip   100%[===================>] 872.84M  4.78MB/s    in 3m 5s
#
# 2026-07-15 10:35:53 (4.73 MB/s) - ‘asr_sinhala_0.zip’ saved [915237858/915237858]

# %%
# !wget https://openslr.trmal.net/resources/52/asr_sinhala_3.zip
# !wget https://openslr.trmal.net/resources/52/asr_sinhala_5.zip
# !wget https://openslr.trmal.net/resources/52/asr_sinhala_6.zip
# !wget https://openslr.trmal.net/resources/52/asr_sinhala_7.zip
# Out:
# --2026-07-15 14:49:47--  https://openslr.trmal.net/resources/52/asr_sinhala_3.zip
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 901325452 (860M) [application/zip]
# Saving to: ‘asr_sinhala_3.zip’
#
# asr_sinhala_3.zip   100%[===================>] 859.57M  9.07MB/s    in 63s
#
# 2026-07-15 14:50:52 (13.6 MB/s) - ‘asr_sinhala_3.zip’ saved [901325452/901325452]
#
# --2026-07-15 14:50:52--  https://openslr.trmal.net/resources/52/asr_sinhala_5.zip
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 922505332 (880M) [application/zip]
# Saving to: ‘asr_sinhala_5.zip’
#
# ...

# %%
# !wget https://openslr.trmal.net/resources/12/train-clean-100.tar.gz
# Out:
# --2026-07-15 14:53:59--  https://openslr.trmal.net/resources/12/train-clean-100.tar.gz
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6387309499 (5.9G) [application/x-gzip]
# Saving to: ‘train-clean-100.tar.gz’
#
# train-clean-100.tar 100%[===================>]   5.95G  13.8MB/s    in 7m 43s
#
# 2026-07-15 15:01:43 (13.2 MB/s) - ‘train-clean-100.tar.gz’ saved [6387309499/6387309499]

# %%
# !wget https://openslr.trmal.net/resources/52/asr_sinhala_1.zip
# !wget https://openslr.trmal.net/resources/52/asr_sinhala_2.zip
# Out:
# --2026-07-15 10:35:53--  https://openslr.trmal.net/resources/52/asr_sinhala_1.zip
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 908852134 (867M) [application/zip]
# Saving to: ‘asr_sinhala_1.zip’
#
# asr_sinhala_1.zip   100%[===================>] 866.75M  6.23MB/s    in 2m 56s
#
# 2026-07-15 10:38:50 (4.93 MB/s) - ‘asr_sinhala_1.zip’ saved [908852134/908852134]
#
# --2026-07-15 10:38:50--  https://openslr.trmal.net/resources/52/asr_sinhala_2.zip
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 913568157 (871M) [application/zip]
# Saving to: ‘asr_sinhala_2.zip’
#
# ...

# %%
#!unzip -q asr_sinhala_0.zip -d ./sinhala_audio/
# !wget https://openslr.trmal.net/resources/52/utt_spk_text.tsv
# Out:
# --2026-07-15 12:44:05--  https://openslr.trmal.net/resources/52/utt_spk_text.tsv
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16153717 (15M) [text/tab-separated-values]
# Saving to: ‘utt_spk_text.tsv’
#
# utt_spk_text.tsv    100%[===================>]  15.41M  5.63MB/s    in 2.7s
#
# 2026-07-15 12:44:09 (5.63 MB/s) - ‘utt_spk_text.tsv’ saved [16153717/16153717]

# %%
# !unzip -q asr_sinhala_1.zip -d ./sinhala_audio1/
# !unzip -q asr_sinhala_2.zip -d ./sinhala_audio2/

# %%
def get_files():
  files = []
  paths = {}

  for i in ["sinhala_audio", "sinhala_audio1", "sinhala_audio2"]:
    p = '/content/' + i + '/asr_sinhala/data/'
    for f in os.listdir(p):
      for file in os.listdir(p+f):
          files.append(file.replace(".flac", ''))
          paths[file.replace(".flac", '')] = p+f+'/'+file
  return files, paths
# Out:
# (['0ce492e088',
#   '0c4e5d24fc',
#   '0cffdce4e6',
#   '0cb12fe61b',
#   '0c7917bf7b',
#   '0c04cafa8a',
#   '0c64e72c7d',
#   '0c890a9277',
#   '0c2b3f3c47',
#   '0c49a4a7e5',
#   '0c04235a87',
#   '0c08ea307b',
#   '0c35a980fe',
#   '0ccac4b684',
#   '0c51764595',
#   '0c4f6577ce',
#   '0c7f45a822',
#   '0c47a0c95b',
#   '0c972c54db',
#   '0c291851f9',
#   '0c9728402f',
#   '0ceb30dec8',
#   '0c0143e76a',
#   '0c53f84270',
#   '0cd63dae3b',
#   '0c166977a6',
#   '0c242f4416',
#   '0c80a39664',
#   '0c6aeb7628',
#   '0ca3cb2252',
#   '0c492afcd8',
#   '0c5f843a51',
#   '0ce6a39b03',
#   '0ce12593b5',
#   '0ccc55cecb',
#   '0ceed11fc7',
#   '0cbea4b7b1',
#   '0cee894ef0',
#   '0c7045d5f6',
#   '0c75eb3d02',
#   '0cb1407ad3',
#   '0c881947b2',
#   '0cad6ee493',
#   '0cc2f59007',
#   '0c0352f56e',
#   '0c0a23b6ca',
#   '0c6d541e61',
#   '0c7b48a467',
#   '0cf4071815',
#   '0c91c92cc9',
#   '0cbdc12caf',
#   '0cb895f02e',
#   '0c9255f296',
#   '0c8c0f156e',
#   '0c5f53fe28',
# ...

# %%
# !hf auth login
# Out:
# User is already logged in. Use `hf auth login --force` to force re-login.

# %%
import os

# 1. Clear out any sticky environmental variables causing signature errors
if "HF_HUB_ENABLE_HF_TRANSFER" in os.environ:
    del os.environ["HF_HUB_ENABLE_HF_TRANSFER"]

# 2. Kill the buggy Xet framework entirely so it falls back to standard HTTP
os.environ["HF_HUB_DISABLE_XET"] = "1"
os.environ["HF_XET_HIGH_PERFORMANCE"] = "0"
os.environ["HF_HUB_OFFLINE"] = "0"
os.environ["HF_DEBUG"] = "1"

# 3. Download the model entirely unauthenticated (No --token flag)

# %%
from google.colab import userdata
token = userdata.get('HF_TOKEN')

# %%
# !hf download facebook/wav2vec2-xls-r-300m --local-dir ./xlsr_model_dir
# Out:
# Request a94fe707-4714-468e-bda5-cf1a4f61f026: GET https://huggingface.co/api/models/facebook/wav2vec2-xls-r-300m/revision/main (authenticated: True)
# Send: curl -X GET -H 'accept: */*' -H 'accept-encoding: gzip, deflate, br, zstd' -H 'authorization: <TOKEN>' -H 'connection: keep-alive' -H 'host: huggingface.co' -H 'user-agent: huggingface-cli/None; hf_hub/1.20.1; python/3.12.13; torch/2.11.0+cu128' -H 'x-amzn-trace-id: a94fe707-4714-468e-bda5-cf1a4f61f026' -d https://huggingface.co/api/models/facebook/wav2vec2-xls-r-300m/revision/main
# ...
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]Request 43abd99c-6b70-4f7b-b1e4-5eaa38e9b78a: HEAD https://huggingface.co/facebook/wav2vec2-xls-r-300m/resolve/1a640f32ac3e39899438a2931f9924c02f080a54/README.md (authenticated: True)
# ...

# %%
# !hf download speechbrain/spkrec-ecapa-voxceleb --local-dir tmpdir
# Out:
# ...
# Fetching 10 files: 100% 10/10 [00:00<00:00, 34.32it/s]
# Download complete: 100% 5.53M/5.53M [00:00<00:00, 18.5MB/s]                ✓ Downloaded
#   path: /content/tmpdir
# Download complete: 100% 5.53M/5.53M [00:00<00:00, 17.2MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# asr_sinhala_0.zip  drive  sample_data  sinhala_audio  tmpdir  utt_spk_text.tsv

# %%
import shutil

# Replace 'my_file.txt' with your actual file name
# Replace 'My_Folder' with your specific Drive folder name (optional)
#shutil.copytree("/content/xlsr_model_dir", "/content/drive/MyDrive/Data_Science_Project/Models/Original")
shutil.copytree("/content/tmpdir", "/content/drive/MyDrive/Data_Science_Project/Models/Original1")
# Out:
# '/content/drive/MyDrive/Data_Science_Project/Models/Original1'

# %%
# !pip install speechbrain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 61.0 MB/s eta 0:00:00
# ...

# %%
import os
import torch
import torchaudio
import pandas as pd
import torch.nn.functional as F
import random
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Model

try:
    from speechbrain.inference.speaker import EncoderClassifier
except ImportError:
    from speechbrain.pretrained import EncoderClassifier

os.environ["HF_HUB_OFFLINE"] = "1"

def run_sinhala_comparison():
    print("1. Parsing Local Sinhala Dataset...")

    # Load metadata
    metadata = pd.read_csv(
        'utt_spk_text.tsv',
        sep='\t',
        header=None,
        names=['FileID', 'UserID', 'Transcription']
    )

    # Find valid local files

    local_files, paths = get_files()
    available_data = metadata[metadata['FileID'].isin(local_files)]

    # Group by speaker to find valid candidates (need Speaker A with >=2 files, Speaker B with >=1)
    spk_counts = available_data['UserID'].value_counts()
    valid_spks = spk_counts[spk_counts >= 2].index.tolist()

    print("AAAAAAAAAAAAAAAAAAA", len(spk_counts))

    if len(valid_spks) < 2:
        raise ValueError("Not enough speakers with multiple utterances downloaded. Download more zips.")

    spk_A = valid_spks[0]
    spk_B = valid_spks[1]

    files_A = available_data[available_data['UserID'] == spk_A]['FileID'].tolist()
    files_B = available_data[available_data['UserID'] == spk_B]['FileID'].tolist()

    print(f"   -> Selected Speaker A (ID: {spk_A}) and Speaker B (ID: {spk_B})\n")

    # Load audio and ensure 16kHz sample rate
    def load_and_resample(file_id):
        path = paths[file_id]
        waveform, sr = torchaudio.load(path)
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        # Convert stereo to mono if necessary
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    audio_A1 = load_and_resample(files_A[0])
    audio_A2 = load_and_resample(files_A[1])
    audio_B1 = load_and_resample(files_B[0])

    print("2. Loading Method 1: ECAPA-TDNN (SpeechBrain)...")
    ecapa_classifier = EncoderClassifier.from_hparams(source="tmpdir  ", savedir="tmpdir")

    print("3. Loading Method 2: XLS-R 300M (HuggingFace)...")
    # XLS-R is a raw foundation model, so we load the base model and mean-pool its hidden states
    xlsr_extractor = Wav2Vec2FeatureExtractor.from_pretrained("/xlsr_model_dir")
    xlsr_model = Wav2Vec2Model.from_pretrained("/xlsr_model_dir")

    cos = torch.nn.CosineSimilarity(dim=-1)

    def get_ecapa_embedding(audio_array):
        signal = torch.tensor(audio_array).unsqueeze(0).float()
        with torch.no_grad():
            emb = ecapa_classifier.encode_batch(signal).squeeze(1)
            return F.normalize(emb, p=2, dim=-1)

    def get_xlsr_embedding(audio_array):
        inputs = xlsr_extractor(audio_array, sampling_rate=16000, return_tensors="pt", padding=True)
        with torch.no_grad():
            outputs = xlsr_model(**inputs)
            # Mean pooling across the time dimension to create a single vector per utterance
            emb = outputs.last_hidden_state.mean(dim=1)
            return F.normalize(emb, p=2, dim=-1)

    print("\n4. Running Inference & Calculating Metrics...")

    # --- ECAPA-TDNN Evaluation ---
    ecapa_A1 = get_ecapa_embedding(audio_A1)
    ecapa_A2 = get_ecapa_embedding(audio_A2)
    ecapa_B1 = get_ecapa_embedding(audio_B1)

    ecapa_same = cos(ecapa_A1, ecapa_A2).item()
    ecapa_diff = cos(ecapa_A1, ecapa_B1).item()
    ecapa_margin = ecapa_same - ecapa_diff

    # --- XLS-R Evaluation ---
    xlsr_A1 = get_xlsr_embedding(audio_A1)
    xlsr_A2 = get_xlsr_embedding(audio_A2)
    xlsr_B1 = get_xlsr_embedding(audio_B1)

    xlsr_same = cos(xlsr_A1, xlsr_A2).item()
    xlsr_diff = cos(xlsr_A1, xlsr_B1).item()
    xlsr_margin = xlsr_same - xlsr_diff

    print("\n" + "="*60)
    print("RESULTS: ZERO-SHOT SINHALA SPEAKER VERIFICATION")
    print("="*60)

    print(f"\n[Method 1] ECAPA-TDNN (Trained on English SV)")
    print(f"Similarity (Same Speaker) : {ecapa_same:.4f}")
    print(f"Similarity (Diff Speaker) : {ecapa_diff:.4f}")
    print(f"Discrimination Margin     : {ecapa_margin:.4f}  (Higher = Better separation)")

    print(f"\n[Method 2] XLS-R 300M (Multilingual Foundation Model)")
    print(f"Similarity (Same Speaker) : {xlsr_same:.4f}")
    print(f"Similarity (Diff Speaker) : {xlsr_diff:.4f}")
    print(f"Discrimination Margin     : {xlsr_margin:.4f}  (Higher = Better separation)")
    print("\n" + "="*60)

run_sinhala_comparison()
# Out:
# 1. Parsing Local Sinhala Dataset...
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using file found at '/content/tmpdir/hyperparams.yaml'
# AAAAAAAAAAAAAAAAAAA 478
#    -> Selected Speaker A (ID: 78366) and Speaker B (ID: 0b586)
#
# 2. Loading Method 1: ECAPA-TDNN (SpeechBrain)...
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using file found at '/content/tmpdir/embedding_model.ckpt'
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using file found at '/content/tmpdir/mean_var_norm_emb.ckpt'
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using file found at '/content/tmpdir/classifier.ckpt'
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/tmpdir/label_encoder.ckpt'
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# ...

# %%
import os
import torch
import torchaudio
import pandas as pd
import torch.nn.functional as F
import random
import numpy as np
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Model

try:
    from speechbrain.inference.speaker import EncoderClassifier
except ImportError:
    from speechbrain.pretrained import EncoderClassifier

os.environ["HF_HUB_OFFLINE"] = "1"

# ==========================================
# 1. DEVICE DETECTION (Targets GPU if available)
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🚀 Running on device: {device.type.upper()}")

def calculate_eer(pos_scores, neg_scores):
    if len(pos_scores) == 0 or len(neg_scores) == 0:
        return 0.0, 0.0

    y_scores = np.array(pos_scores + neg_scores)
    thresholds = np.sort(y_scores)

    min_diff = float('inf')
    best_eer = 1.0
    best_thresh = 0.0

    for t in thresholds:
        far = np.mean(np.array(neg_scores) >= t)
        frr = np.mean(np.array(pos_scores) < t)

        diff = abs(far - frr)
        if diff < min_diff:
            min_diff = diff
            best_eer = (far + frr) / 2.0
            best_thresh = t

    return best_eer * 100, best_thresh

def run_sinhala_comparison():
    print("1. Parsing Local Sinhala Dataset...")

    # Load metadata
    metadata = pd.read_csv(
        'utt_spk_text.tsv',
        sep='\t',
        header=None,
        names=['FileID', 'UserID', 'Transcription']
    )

    # Get local files from your custom function
    local_files, paths = get_files()
    available_data = metadata[metadata['FileID'].isin(local_files)]

    # Group available files by speaker
    spk_to_files = available_data.groupby('UserID')['FileID'].apply(list).to_dict()
    all_speakers = list(spk_to_files.keys())

    # 2. Construct Balanced Evaluation Trials
    print("2. Generating Evaluation Trials...")
    positive_pairs = []
    negative_pairs = []

    MAX_PAIRS = 5000
    upper_bound = 700_000

    for spk, files in spk_to_files.items():
        if len(files) >= 2:
            for i in range(len(files)):
                for j in range(i + 1, len(files)):
                    positive_pairs.append((files[i], files[j]))
                    if len(positive_pairs) % 50_000 == 0:
                        print(f"   -> Generated {len(positive_pairs)} Same-Speaker trials.")

    random.seed(42)
    random.shuffle(positive_pairs)
    positive_pairs = positive_pairs[:MAX_PAIRS]

    for f1, _ in positive_pairs:
        spk1 = available_data[available_data['FileID'] == f1]['UserID'].values[0]
        other_speakers = [s for s in all_speakers if s != spk1]

        if other_speakers:
            random_other_spk = random.choice(other_speakers)
            random_other_file = random.choice(spk_to_files[random_other_spk])
            negative_pairs.append((f1, random_other_file))

            if len(negative_pairs) % 50_000 == 0:
                print(f"   -> Generated {len(negative_pairs)} Different-Speaker trials.")

    random.shuffle(negative_pairs)

    negative_pairs = negative_pairs[:len(positive_pairs)]

    print(f"   -> Generated {len(positive_pairs)} Same-Speaker trials.")
    print(f"   -> Generated {len(negative_pairs)} Different-Speaker trials.")

    eval_files = list(set([f for pair in positive_pairs for f in pair] +
                          [f for pair in negative_pairs for f in pair]))
    print(f"   -> Found {len(eval_files)} unique files to process.")

    # We keep torchaudio loader on CPU (standard practice as file I/O is handled on CPU)
    def load_and_resample(file_id):
        path = paths[file_id]
        waveform, sr = torchaudio.load(path)
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    # ==========================================
    # 3. LOAD MODELS DIRECTLY TO GPU
    # ==========================================
    print("\n3. Loading Models onto GPU...")
    # Speechbrain uses 'run_opts' dictionary to automatically set target device
    ecapa_classifier = EncoderClassifier.from_hparams(
        source="tmpdir",
        savedir="tmpdir",
        run_opts={"device": str(device)}
    )

    xlsr_extractor = Wav2Vec2FeatureExtractor.from_pretrained("./xlsr_model_dir")

    # Hugging Face models are pushed to GPU explicitly via `.to(device)`
    xlsr_model = Wav2Vec2Model.from_pretrained("./xlsr_model_dir").to(device)
    xlsr_model.eval()

    # ==========================================
    # 4. EXPLICITLY PUSH INPUTS TO GPU
    # ==========================================
    def get_ecapa_embedding(audio_array):
        signal = torch.tensor(audio_array).unsqueeze(0).float().to(device)
        with torch.no_grad():
            emb = ecapa_classifier.encode_batch(signal).squeeze(1)
            return F.normalize(emb, p=2, dim=-1)

    def get_xlsr_embedding(audio_array):
        inputs = xlsr_extractor(audio_array, sampling_rate=16000, return_tensors="pt", padding=True)
        # Hugging Face inputs (dictionary of tensors) need to be recursively pushed to GPU
        inputs = {k: v.to(device) for k, v in inputs.items()}
        with torch.no_grad():
            outputs = xlsr_model(**inputs)
            emb = outputs.last_hidden_state.mean(dim=1)
            return F.normalize(emb, p=2, dim=-1)

    # 5. Single-Pass Embedding Extraction
    print("\n4. Running Single-Pass Inference on local Sinhala files...")
    ecapa_cache = {}
    xlsr_cache = {}

    for idx, f_id in enumerate(eval_files):
        if idx % 50 == 0 or idx == len(eval_files) - 1:
            print(f"   -> Processing file {idx + 1}/{len(eval_files)}")

        try:
            audio_data = load_and_resample(f_id)
            ecapa_cache[f_id] = get_ecapa_embedding(audio_data)
            xlsr_cache[f_id] = get_xlsr_embedding(audio_data)
        except Exception as e:
            print(f"      [Warning] Error loading {f_id}: {e}")
            continue

    # 6. Evaluate Pairs using cached GPU embeddings
    print("\n5. Computing Pairwise Similarity Scores...")
    cos = torch.nn.CosineSimilarity(dim=-1)

    ecapa_pos_scores = []
    ecapa_neg_scores = []
    xlsr_pos_scores = []
    xlsr_neg_scores = []

    for f1, f2 in positive_pairs:
        if f1 in ecapa_cache and f2 in ecapa_cache:
            # .item() pulls the single-element GPU tensor back to a CPU float
            ecapa_pos_scores.append(cos(ecapa_cache[f1], ecapa_cache[f2]).item())
            xlsr_pos_scores.append(cos(xlsr_cache[f1], xlsr_cache[f2]).item())

    for f1, f2 in negative_pairs:
        if f1 in ecapa_cache and f2 in ecapa_cache:
            ecapa_neg_scores.append(cos(ecapa_cache[f1], ecapa_cache[f2]).item())
            xlsr_neg_scores.append(cos(xlsr_cache[f1], xlsr_cache[f2]).item())

    # 7. Calculate Metrics
    ecapa_avg_pos = np.mean(ecapa_pos_scores) if ecapa_pos_scores else 0
    ecapa_avg_neg = np.mean(ecapa_neg_scores) if ecapa_neg_scores else 0
    ecapa_margin = ecapa_avg_pos - ecapa_avg_neg
    ecapa_eer, ecapa_thresh = calculate_eer(ecapa_pos_scores, ecapa_neg_scores)

    xlsr_avg_pos = np.mean(xlsr_pos_scores) if xlsr_pos_scores else 0
    xlsr_avg_neg = np.mean(xlsr_neg_scores) if xlsr_neg_scores else 0
    xlsr_margin = xlsr_avg_pos - xlsr_avg_neg
    xlsr_eer, xlsr_thresh = calculate_eer(xlsr_pos_scores, xlsr_neg_scores)

    # 8. Print Results Table
    print("\n" + "="*70)
    print("RESULTS: MASS EVALUATION ON SINHALA AUDIO DATASET")
    print("="*70)

    metrics_summary = pd.DataFrame({
        "Metric": [
            "Average Same-Speaker Sim",
            "Average Diff-Speaker Sim",
            "Separation Margin (↑)",
            "Best Decision Threshold",
            "Equal Error Rate (EER % ↓)"
        ],
        "ECAPA-TDNN": [
            f"{ecapa_avg_pos:.4f}",
            f"{ecapa_avg_neg:.4f}",
            f"{ecapa_margin:.4f}",
            f"{ecapa_thresh:.4f}",
            f"{ecapa_eer:.2f}%"
        ],
        "XLS-R 300M": [
            f"{xlsr_avg_pos:.4f}",
            f"{xlsr_avg_neg:.4f}",
            f"{xlsr_margin:.4f}",
            f"{xlsr_thresh:.4f}",
            f"{xlsr_eer:.2f}%"
        ]
    })
    print(metrics_summary.to_string(index=False))
    print("="*70)

run_sinhala_comparison()
# Out:
# 🚀 Running on device: CUDA
# 1. Parsing Local Sinhala Dataset...
# 2. Generating Evaluation Trials...
#    -> Generated 50000 Same-Speaker trials.
#    -> Generated 100000 Same-Speaker trials.
#    -> Generated 150000 Same-Speaker trials.
#    -> Generated 200000 Same-Speaker trials.
#    -> Generated 250000 Same-Speaker trials.
#    -> Generated 300000 Same-Speaker trials.
#    -> Generated 350000 Same-Speaker trials.
#    -> Generated 400000 Same-Speaker trials.
#    -> Generated 450000 Same-Speaker trials.
#    -> Generated 500000 Same-Speaker trials.
#    -> Generated 550000 Same-Speaker trials.
#    -> Generated 600000 Same-Speaker trials.
#    -> Generated 650000 Same-Speaker trials.
#    -> Generated 700000 Same-Speaker trials.
#    -> Generated 750000 Same-Speaker trials.
#    -> Generated 800000 Same-Speaker trials.
#    -> Generated 850000 Same-Speaker trials.
#    -> Generated 900000 Same-Speaker trials.
# ...

# %%
# !wget https://openslr.trmal.net/resources/12/dev-clean.tar.gz
# Out:
# --2026-07-14 18:09:03--  https://openslr.trmal.net/resources/12/dev-clean.tar.gz
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 337926286 (322M) [application/x-gzip]
# Saving to: ‘dev-clean.tar.gz’
#
# dev-clean.tar.gz    100%[===================>] 322.27M  8.84MB/s    in 28s
#
# 2026-07-14 18:09:31 (11.7 MB/s) - ‘dev-clean.tar.gz’ saved [337926286/337926286]

# %%
# !tar -xvf dev-clean.tar.gz
# Out:
# LibriSpeech/LICENSE.TXT
# LibriSpeech/README.TXT
# LibriSpeech/CHAPTERS.TXT
# LibriSpeech/SPEAKERS.TXT
# LibriSpeech/BOOKS.TXT
# LibriSpeech/dev-clean/
# LibriSpeech/dev-clean/2277/
# LibriSpeech/dev-clean/2277/149896/
# LibriSpeech/dev-clean/2277/149896/2277-149896-0026.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0005.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0033.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0006.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0018.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0034.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0021.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0015.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0012.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0027.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0007.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0030.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0011.flac
# ...

# %%
import os
import torch
import torchaudio
import pandas as pd
import torch.nn.functional as F
import random
import numpy as np
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Model

try:
    from speechbrain.inference.speaker import EncoderClassifier
except ImportError:
    from speechbrain.pretrained import EncoderClassifier

# Set to "0" if you want to pull models automatically from Hugging Face / SpeechBrain
os.environ["HF_HUB_OFFLINE"] = "1"

# ==========================================
# 1. DEVICE DETECTION (Targets GPU if available)
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🚀 Running on device: {device.type.upper()}")

def calculate_eer(pos_scores, neg_scores):
    if len(pos_scores) == 0 or len(neg_scores) == 0:
        return 0.0, 0.0

    y_scores = np.array(pos_scores + neg_scores)
    thresholds = np.sort(y_scores)

    min_diff = float('inf')
    best_eer = 1.0
    best_thresh = 0.0

    for t in thresholds:
        far = np.mean(np.array(neg_scores) >= t)
        frr = np.mean(np.array(pos_scores) < t)

        diff = abs(far - frr)
        if diff < min_diff:
            min_diff = diff
            best_eer = (far + frr) / 2.0
            best_thresh = t

    return best_eer * 100, best_thresh

def run_librispeech_comparison():
    # ==========================================
    # 2. LOAD LIBRISPEECH DEV-CLEAN DATASET
    # ==========================================
    print("1. Loading LibriSpeech dev-clean dataset...")
    # Downloads ~337 MB of dev-clean into ./ if not already present
    dataset = torchaudio.datasets.LIBRISPEECH(root="./", url="dev-clean", download=True)
    print(f"   -> Loaded {len(dataset)} total utterances.")

    # Speed up parsing: Build an index mapping of speaker IDs using fast metadata inspection
    print("   -> Mapping speaker identities...")
    idx_to_spk = {}
    for idx in range(len(dataset)):
        # get_metadata yields speaker ID without reading the heavy raw FLAC waveforms into RAM
        _, _, _, speaker_id, _, _ = dataset.get_metadata(idx)
        idx_to_spk[idx] = speaker_id

    # Group dataset indices by speaker
    spk_to_indices = {}
    for idx, spk in idx_to_spk.items():
        if spk not in spk_to_indices:
            spk_to_indices[spk] = []
        spk_to_indices[spk].append(idx)

    all_speakers = list(spk_to_indices.keys())
    print(f"   -> Found {len(all_speakers)} unique speakers in the split.")

    # ==========================================
    # 3. GENERATE TRIAL PAIRS
    # ==========================================
    print("2. Generating Evaluation Trials...")
    positive_pairs = []
    negative_pairs = []

    MAX_PAIRS = 5000  # Number of verification trials to test (adjustable)

    # Generate same-speaker positive trials
    for spk, indices in spk_to_indices.items():
        if len(indices) >= 2:
            for i in range(len(indices)):
                for j in range(i + 1, len(indices)):
                    positive_pairs.append((indices[i], indices[j]))

    random.seed(42)
    random.shuffle(positive_pairs)
    positive_pairs = positive_pairs[:MAX_PAIRS]

    # Generate balanced different-speaker negative trials
    for idx1, _ in positive_pairs:
        spk1 = idx_to_spk[idx1]
        other_speakers = [s for s in all_speakers if s != spk1]

        if other_speakers:
            random_other_spk = random.choice(other_speakers)
            random_other_idx = random.choice(spk_to_indices[random_other_spk])
            negative_pairs.append((idx1, random_other_idx))

    negative_pairs = negative_pairs[:len(positive_pairs)]

    print(f"   -> Generated {len(positive_pairs)} Same-Speaker trials.")
    print(f"   -> Generated {len(negative_pairs)} Different-Speaker trials.")

    # Gather all unique indices we actually need to compute embeddings for
    eval_indices = list(set([idx for pair in positive_pairs for idx in pair] +
                            [idx for pair in negative_pairs for idx in pair]))
    print(f"   -> Found {len(eval_indices)} unique utterances to process.")

    # Audio loading function tailored for LibriSpeech output
    def load_and_resample(dataset_idx):
        waveform, sr, _, _, _, _ = dataset[dataset_idx]
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    # ==========================================
    # 4. LOAD MODEL EMBEDDING ENGINES
    # ==========================================
    print("\n3. Loading Models onto GPU...")

    # --- MODEL 1: ECAPA-TDNN ---
    # Offline source: "tmpdir" / Online source: "speechbrain/spkrec-ecapa-voxceleb"
    ecapa_source = "tmpdir" if os.environ["HF_HUB_OFFLINE"] == "1" else "speechbrain/spkrec-ecapa-voxceleb"
    ecapa_classifier = EncoderClassifier.from_hparams(
        source=ecapa_source,
        savedir="tmpdir",
        run_opts={"device": str(device)}
    )

    # --- MODEL 2: XLS-R ---
    # Offline source: "./xlsr_model_dir" / Online source: "facebook/wav2vec2-xls-r-300m"
    xlsr_source = "./xlsr_model_dir" if os.environ["HF_HUB_OFFLINE"] == "1" else "facebook/wav2vec2-xls-r-300m"
    xlsr_extractor = Wav2Vec2FeatureExtractor.from_pretrained(xlsr_source)
    xlsr_model = Wav2Vec2Model.from_pretrained(xlsr_source).to(device)
    xlsr_model.eval()

    def get_ecapa_embedding(audio_array):
        signal = torch.tensor(audio_array).unsqueeze(0).float().to(device)
        with torch.no_grad():
            emb = ecapa_classifier.encode_batch(signal).squeeze(1)
            return F.normalize(emb, p=2, dim=-1)

    def get_xlsr_embedding(audio_array):
        inputs = xlsr_extractor(audio_array, sampling_rate=16000, return_tensors="pt", padding=True)
        inputs = {k: v.to(device) for k, v in inputs.items()}
        with torch.no_grad():
            outputs = xlsr_model(**inputs)
            emb = outputs.last_hidden_state.mean(dim=1)
            return F.normalize(emb, p=2, dim=-1)

    # ==========================================
    # 5. SINGLE-PASS CACHED INFERENCE
    # ==========================================
    print("\n4. Running Single-Pass Inference on LibriSpeech dev-clean files...")
    ecapa_cache = {}
    xlsr_cache = {}

    for idx, eval_idx in enumerate(eval_indices):
        if idx % 50 == 0 or idx == len(eval_indices) - 1:
            print(f"   -> Processing file {idx + 1}/{len(eval_indices)}")

        try:
            audio_data = load_and_resample(eval_idx)
            ecapa_cache[eval_idx] = get_ecapa_embedding(audio_data)
            xlsr_cache[eval_idx] = get_xlsr_embedding(audio_data)
        except Exception as e:
            print(f"      [Warning] Error processing index {eval_idx}: {e}")
            continue

    # ==========================================
    # 6. EVALUATE EMBEDDINGS
    # ==========================================
    print("\n5. Computing Pairwise Similarity Scores...")
    cos = torch.nn.CosineSimilarity(dim=-1)

    ecapa_pos_scores = []
    ecapa_neg_scores = []
    xlsr_pos_scores = []
    xlsr_neg_scores = []

    for idx1, idx2 in positive_pairs:
        if idx1 in ecapa_cache and idx2 in ecapa_cache:
            ecapa_pos_scores.append(cos(ecapa_cache[idx1], ecapa_cache[idx2]).item())
            xlsr_pos_scores.append(cos(xlsr_cache[idx1], xlsr_cache[idx2]).item())

    for idx1, idx2 in negative_pairs:
        if idx1 in ecapa_cache and idx2 in ecapa_cache:
            ecapa_neg_scores.append(cos(ecapa_cache[idx1], ecapa_cache[idx2]).item())
            xlsr_neg_scores.append(cos(xlsr_cache[idx1], xlsr_cache[idx2]).item())

    # Calculate metrics
    ecapa_avg_pos = np.mean(ecapa_pos_scores) if ecapa_pos_scores else 0
    ecapa_avg_neg = np.mean(ecapa_neg_scores) if ecapa_neg_scores else 0
    ecapa_margin = ecapa_avg_pos - ecapa_avg_neg
    ecapa_eer, ecapa_thresh = calculate_eer(ecapa_pos_scores, ecapa_neg_scores)

    xlsr_avg_pos = np.mean(xlsr_pos_scores) if xlsr_pos_scores else 0
    xlsr_avg_neg = np.mean(xlsr_neg_scores) if xlsr_neg_scores else 0
    xlsr_margin = xlsr_avg_pos - xlsr_avg_neg
    xlsr_eer, xlsr_thresh = calculate_eer(xlsr_pos_scores, xlsr_neg_scores)

    # Print results
    print("\n" + "="*70)
    print("RESULTS: MASS EVALUATION ON LIBRISPEECH (DEV-CLEAN)")
    print("="*70)

    metrics_summary = pd.DataFrame({
        "Metric": [
            "Average Same-Speaker Sim",
            "Average Diff-Speaker Sim",
            "Separation Margin (↑)",
            "Best Decision Threshold",
            "Equal Error Rate (EER % ↓)"
        ],
        "ECAPA-TDNN": [
            f"{ecapa_avg_pos:.4f}",
            f"{ecapa_avg_neg:.4f}",
            f"{ecapa_margin:.4f}",
            f"{ecapa_thresh:.4f}",
            f"{ecapa_eer:.2f}%"
        ],
        "XLS-R 300M": [
            f"{xlsr_avg_pos:.4f}",
            f"{xlsr_avg_neg:.4f}",
            f"{xlsr_margin:.4f}",
            f"{xlsr_thresh:.4f}",
            f"{xlsr_eer:.2f}%"
        ]
    })
    print(metrics_summary.to_string(index=False))
    print("="*70)

run_librispeech_comparison()
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using file found at '/content/tmpdir/hyperparams.yaml'
# 🚀 Running on device: CUDA
# 1. Loading LibriSpeech dev-clean dataset...
#    -> Loaded 2703 total utterances.
#    -> Mapping speaker identities...
#    -> Found 40 unique speakers in the split.
# 2. Generating Evaluation Trials...
#    -> Generated 500 Same-Speaker trials.
#    -> Generated 500 Different-Speaker trials.
#    -> Found 1167 unique utterances to process.
#
# 3. Loading Models onto GPU...
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using file found at '/content/tmpdir/embedding_model.ckpt'
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using file found at '/content/tmpdir/mean_var_norm_emb.ckpt'
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using file found at '/content/tmpdir/classifier.ckpt'
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/tmpdir/label_encoder.ckpt'
# ...

# %%
# !hf download speechbrain/spkrec-xvect-voxceleb --local-dir x-vector
# Out:
# Request 6b28cb0a-0309-4a46-80fd-31b70c3440cd: GET https://huggingface.co/api/models/speechbrain/spkrec-xvect-voxceleb/revision/main (authenticated: True)
# Send: curl -X GET -H 'accept: */*' -H 'accept-encoding: gzip, deflate, br, zstd' -H 'authorization: <TOKEN>' -H 'connection: keep-alive' -H 'host: huggingface.co' -H 'user-agent: huggingface-cli/None; hf_hub/1.20.1; python/3.12.13; torch/2.11.0+cu128' -H 'x-amzn-trace-id: 6b28cb0a-0309-4a46-80fd-31b70c3440cd' -d https://huggingface.co/api/models/speechbrain/spkrec-xvect-voxceleb/revision/main
# ...
# Fetching 9 files:   0% 0/9 [00:00<?, ?it/s]Request 7f74b057-514e-4613-9170-5900c6332236: HEAD https://huggingface.co/speechbrain/spkrec-xvect-voxceleb/resolve/56895a2df401be4150a159f3a1c653f00051d477/embedding_model.ckpt (authenticated: True)
# ...

# %%
import os
import torch
import torchaudio
import pandas as pd
import torch.nn.functional as F
import random
import numpy as np

try:
    from speechbrain.inference.speaker import EncoderClassifier
except ImportError:
    from speechbrain.pretrained import EncoderClassifier

# =====================================================================
# CONFIGURATION
# Set OFFLINE_MODE to True if you are running in an offline environment
# and have pre-downloaded the models to local directories.
# =====================================================================
OFFLINE_MODE = True

if OFFLINE_MODE:
    os.environ["HF_HUB_OFFLINE"] = "1"
    ECAPA_SOURCE = "/content/tmpdir" # Replace with your local path if offline
    XVECT_SOURCE = "/content/x-vector" # Replace with your local path if offline
else:
    os.environ["HF_HUB_OFFLINE"] = "0"
    ECAPA_SOURCE = "speechbrain/spkrec-ecapa-voxceleb"
    XVECT_SOURCE = "speechbrain/spkrec-xvect-voxceleb"

# Device detection
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🚀 Running on device: {device.type.upper()}")

# =====================================================================
# HELPER FUNCTIONS
# =====================================================================
def calculate_eer(pos_scores, neg_scores):
    if len(pos_scores) == 0 or len(neg_scores) == 0:
        return 0.0, 0.0

    y_scores = np.array(pos_scores + neg_scores)
    thresholds = np.sort(y_scores)

    min_diff = float('inf')
    best_eer = 1.0
    best_thresh = 0.0

    for t in thresholds:
        far = np.mean(np.array(neg_scores) >= t)
        frr = np.mean(np.array(pos_scores) < t)

        diff = abs(far - frr)
        if diff < min_diff:
            min_diff = diff
            best_eer = (far + frr) / 2.0
            best_thresh = t

    return best_eer * 100, best_thresh


def get_embedding(audio_array, classifier):
    """
    Extracts L2-normalized speaker embeddings. Works for both
    ECAPA-TDNN and X-Vector classifiers.
    """
    signal = torch.tensor(audio_array).unsqueeze(0).float().to(device)
    with torch.no_grad():
        emb = classifier.encode_batch(signal).squeeze(1)
        return F.normalize(emb, p=2, dim=-1)


# =====================================================================
# DATASET GENERATORS
# =====================================================================
def get_sinhala_trials(max_pairs=1000):
    print("-> Parsing Local Sinhala Dataset...")
    metadata = pd.read_csv(
        'utt_spk_text.tsv',
        sep='\t',
        header=None,
        names=['FileID', 'UserID', 'Transcription']
    )

    local_files, paths = get_files() # Calls your custom file getter
    available_data = metadata[metadata['FileID'].isin(local_files)]

    spk_to_files = available_data.groupby('UserID')['FileID'].apply(list).to_dict()
    all_speakers = list(spk_to_files.keys())

    positive_pairs = []
    for spk, files in spk_to_files.items():
        if len(files) >= 2:
            for i in range(len(files)):
                for j in range(i + 1, len(files)):
                    positive_pairs.append((files[i], files[j]))

    random.seed(42)
    random.shuffle(positive_pairs)
    positive_pairs = positive_pairs[:max_pairs]

    negative_pairs = []
    for f1, _ in positive_pairs:
        spk1 = available_data[available_data['FileID'] == f1]['UserID'].values[0]
        other_speakers = [s for s in all_speakers if s != spk1]
        if other_speakers:
            random_other_spk = random.choice(other_speakers)
            random_other_file = random.choice(spk_to_files[random_other_spk])
            negative_pairs.append((f1, random_other_file))

    negative_pairs = negative_pairs[:len(positive_pairs)]
    eval_files = list(set([f for pair in positive_pairs for f in pair] +
                          [f for pair in negative_pairs for f in pair]))

    def load_fn(f_id):
        path = paths[f_id]
        waveform, sr = torchaudio.load(path)
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    return positive_pairs, negative_pairs, eval_files, load_fn


def get_librispeech_trials(max_pairs=1000):
    print("-> Loading LibriSpeech dev-clean dataset...")
    dataset = torchaudio.datasets.LIBRISPEECH(root="./", url="dev-clean", download=True)

    idx_to_spk = {}
    for idx in range(len(dataset)):
        _, _, _, speaker_id, _, _ = dataset.get_metadata(idx)
        idx_to_spk[idx] = speaker_id

    spk_to_indices = {}
    for idx, spk in idx_to_spk.items():
        if spk not in spk_to_indices:
            spk_to_indices[spk] = []
        spk_to_indices[spk].append(idx)

    all_speakers = list(spk_to_indices.keys())

    positive_pairs = []
    for spk, indices in spk_to_indices.items():
        if len(indices) >= 2:
            for i in range(len(indices)):
                for j in range(i + 1, len(indices)):
                    positive_pairs.append((indices[i], indices[j]))

    random.seed(42)
    random.shuffle(positive_pairs)
    positive_pairs = positive_pairs[:max_pairs]

    negative_pairs = []
    for idx1, _ in positive_pairs:
        spk1 = idx_to_spk[idx1]
        other_speakers = [s for s in all_speakers if s != spk1]
        if other_speakers:
            random_other_spk = random.choice(other_speakers)
            random_other_idx = random.choice(spk_to_indices[random_other_spk])
            negative_pairs.append((idx1, random_other_idx))

    negative_pairs = negative_pairs[:len(positive_pairs)]
    eval_indices = list(set([idx for pair in positive_pairs for idx in pair] +
                            [idx for pair in negative_pairs for idx in pair]))

    def load_fn(dataset_idx):
        waveform, sr, _, _, _, _ = dataset[dataset_idx]
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    return positive_pairs, negative_pairs, eval_indices, load_fn


# =====================================================================
# EVALUATOR ENGINE
# =====================================================================
def evaluate_dataset(dataset_name, positive_pairs, negative_pairs, eval_keys, load_fn, ecapa_model, xvect_model):
    print(f"\n--- Running Verification on {dataset_name.upper()} ---")

    # Caching embeddings to prevent duplicate inference runs
    ecapa_cache = {}
    xvect_cache = {}

    for idx, key in enumerate(eval_keys):
        if idx % 100 == 0 or idx == len(eval_keys) - 1:
            print(f"   -> Extracting embeddings: {idx + 1}/{len(eval_keys)}")
        try:
            audio_data = load_fn(key)
            ecapa_cache[key] = get_embedding(audio_data, ecapa_model)
            xvect_cache[key] = get_embedding(audio_data, xvect_model)
        except Exception as e:
            print(f"      [Warning] Error processing key {key}: {e}")
            continue

    cos = torch.nn.CosineSimilarity(dim=-1)

    # Run similarity calculations
    results = {}
    for model_name, cache in [("ECAPA-TDNN", ecapa_cache), ("X-Vector", xvect_cache)]:
        pos_scores = []
        neg_scores = []

        for k1, k2 in positive_pairs:
            if k1 in cache and k2 in cache:
                pos_scores.append(cos(cache[k1], cache[k2]).item())

        for k1, k2 in negative_pairs:
            if k1 in cache and k2 in cache:
                neg_scores.append(cos(cache[k1], cache[k2]).item())

        avg_pos = np.mean(pos_scores) if pos_scores else 0
        avg_neg = np.mean(neg_scores) if neg_scores else 0
        margin = avg_pos - avg_neg
        eer, thresh = calculate_eer(pos_scores, neg_scores)

        results[model_name] = {
            "avg_pos": avg_pos,
            "avg_neg": avg_neg,
            "margin": margin,
            "thresh": thresh,
            "eer": eer
        }

    return results


# =====================================================================
# MAIN EXECUTION
# =====================================================================
def main():
    # 1. Load Models once onto the GPU
    print("1. Loading Models onto GPU...")
    ecapa_model = EncoderClassifier.from_hparams(
        source=ECAPA_SOURCE,
        savedir="tmpdir_ecapa",
        run_opts={"device": str(device)}
    )

    xvect_model = EncoderClassifier.from_hparams(
        source=XVECT_SOURCE,
        savedir="tmpdir_xvect",
        run_opts={"device": str(device)}
    )

    # 2. Get Datasets
    sinhala_pos, sinhala_neg, sinhala_eval, sinhala_load = get_sinhala_trials(max_pairs=500)
    english_pos, english_neg, english_eval, english_load = get_librispeech_trials(max_pairs=500)

    # 3. Run Separated Evaluations
    sinhala_results = evaluate_dataset("Sinhala", sinhala_pos, sinhala_neg, sinhala_eval, sinhala_load, ecapa_model, xvect_model)
    english_results = evaluate_dataset("English (LibriSpeech)", english_pos, english_neg, english_eval, english_load, ecapa_model, xvect_model)

    # 4. Generate Combined Metrics Table
    print("\n" + "="*85)
    print("FINAL ARCHITECTURAL COMPARISON: ECAPA-TDNN VS X-VECTOR")
    print("="*85)

    summary_data = {
        "Metric": [
            "Average Same-Speaker Sim",
            "Average Diff-Speaker Sim",
            "Separation Margin (↑)",
            "Decision Threshold",
            "Equal Error Rate (EER % ↓)"
        ],
        "Sinhala: X-Vector": [
            f"{sinhala_results['X-Vector']['avg_pos']:.4f}",
            f"{sinhala_results['X-Vector']['avg_neg']:.4f}",
            f"{sinhala_results['X-Vector']['margin']:.4f}",
            f"{sinhala_results['X-Vector']['thresh']:.4f}",
            f"{sinhala_results['X-Vector']['eer']:.2f}%"
        ],
        "Sinhala: ECAPA": [
            f"{sinhala_results['ECAPA-TDNN']['avg_pos']:.4f}",
            f"{sinhala_results['ECAPA-TDNN']['avg_neg']:.4f}",
            f"{sinhala_results['ECAPA-TDNN']['margin']:.4f}",
            f"{sinhala_results['ECAPA-TDNN']['thresh']:.4f}",
            f"{sinhala_results['ECAPA-TDNN']['eer']:.2f}%"
        ],
        "English: X-Vector": [
            f"{english_results['X-Vector']['avg_pos']:.4f}",
            f"{english_results['X-Vector']['avg_neg']:.4f}",
            f"{english_results['X-Vector']['margin']:.4f}",
            f"{english_results['X-Vector']['thresh']:.4f}",
            f"{english_results['X-Vector']['eer']:.2f}%"
        ],
        "English: ECAPA": [
            f"{english_results['ECAPA-TDNN']['avg_pos']:.4f}",
            f"{english_results['ECAPA-TDNN']['avg_neg']:.4f}",
            f"{english_results['ECAPA-TDNN']['margin']:.4f}",
            f"{english_results['ECAPA-TDNN']['thresh']:.4f}",
            f"{english_results['ECAPA-TDNN']['eer']:.2f}%"
        ]
    }

    df_summary = pd.DataFrame(summary_data)
    print(df_summary.to_string(index=False))
    print("="*85)

main()
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using symlink found at '/content/tmpdir_ecapa/hyperparams.yaml'
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using symlink found at '/content/tmpdir_ecapa/embedding_model.ckpt'
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using symlink found at '/content/tmpdir_ecapa/mean_var_norm_emb.ckpt'
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using symlink found at '/content/tmpdir_ecapa/classifier.ckpt'
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/tmpdir_ecapa/label_encoder.ckpt'
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# 🚀 Running on device: CUDA
# 1. Loading Models onto GPU...
# WARNING:speechbrain.inference.interfaces:Could not parse CUDA device string 'cuda': not enough values to unpack (expected 2, got 1). Falling back to device 0.
# ...

# %%
"""
Scaled-up ECAPA-TDNN vs X-Vector comparison on Sinhala + English.

FIX SUMMARY vs. previous version:
- Uses ALL available Sinhala speakers (or a configurable target) instead of
  an arbitrary max_pairs cap that under-uses speaker diversity.
- Utterances-per-speaker is capped (not total pairs) so pair count grows
  naturally and predictably with speaker count.
- Per-model cache membership checks are already correct (kept as-is), but
  now also asserts embedding extraction succeeded for BOTH models before
  including a file in trials, avoiding silent partial-cache mismatches.
- get_files() is now an explicit required argument (a function you provide)
  instead of a bare undefined call -- fails loudly with a clear message if
  missing, instead of a cryptic NameError mid-run.

You must still provide `get_files()` yourself: it should return
(local_file_ids, paths_dict) exactly as in your original notebook.
"""

import os
import random
import itertools
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
import torchaudio

try:
    from speechbrain.inference.speaker import EncoderClassifier
except ImportError:
    from speechbrain.pretrained import EncoderClassifier

# =====================================================================
# CONFIGURATION
# =====================================================================
OFFLINE_MODE = True

if OFFLINE_MODE:
    os.environ["HF_HUB_OFFLINE"] = "1"
    ECAPA_SOURCE = "/content/tmpdir"
    XVECT_SOURCE = "/content/x-vector"
else:
    os.environ["HF_HUB_OFFLINE"] = "0"
    ECAPA_SOURCE = "speechbrain/spkrec-ecapa-voxceleb"
    XVECT_SOURCE = "speechbrain/spkrec-xvect-voxceleb"

# --- Speaker/trial scale settings ---
NUM_SPEAKERS_SINHALA = None   # None = use ALL available speakers; or set an int, e.g. 200
UTTS_PER_SPEAKER = 4          # cap per speaker -- controls pair count growth
RANDOM_SEED = 42

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on device: {device.type.upper()}")


# =====================================================================
# METRICS
# =====================================================================
def calculate_eer(pos_scores, neg_scores):
    if len(pos_scores) == 0 or len(neg_scores) == 0:
        return 0.0, 0.0
    pos = np.array(pos_scores)
    neg = np.array(neg_scores)
    thresholds = np.sort(np.concatenate([pos, neg]))

    min_diff = float("inf")
    best_eer, best_thresh = 1.0, 0.0
    for t in thresholds:
        far = np.mean(neg >= t)
        frr = np.mean(pos < t)
        diff = abs(far - frr)
        if diff < min_diff:
            min_diff = diff
            best_eer = (far + frr) / 2.0
            best_thresh = t
    return best_eer * 100, best_thresh


def get_embedding(audio_array, classifier):
    signal = torch.tensor(audio_array).unsqueeze(0).float().to(device)
    with torch.no_grad():
        emb = classifier.encode_batch(signal).squeeze(1)
        return F.normalize(emb, p=2, dim=-1)


# =====================================================================
# TRIAL GENERATION -- speaker-count-driven, not pair-count-driven
# =====================================================================
def build_balanced_trials(spk_to_files: dict, num_speakers: int | None,
                           utts_per_speaker: int, seed: int = 42):
    """
    Selects up to `num_speakers` speakers (all of them if None), caps each
    speaker to `utts_per_speaker` utterances, then builds:
      - positive pairs: all within-speaker combinations of the capped utterances
      - negative pairs: one random cross-speaker match per positive pair
    This maximizes speaker diversity per trial rather than just cranking up
    a raw trial-count cap on a small speaker pool.
    """
    rng = random.Random(seed)

    eligible_speakers = [s for s, files in spk_to_files.items() if len(files) >= 2]
    rng.shuffle(eligible_speakers)
    if num_speakers is not None:
        eligible_speakers = eligible_speakers[:num_speakers]

    capped = {
        spk: spk_to_files[spk][:utts_per_speaker]
        for spk in eligible_speakers
    }

    positive_pairs = []
    for spk, files in capped.items():
        for f1, f2 in itertools.combinations(files, 2):
            positive_pairs.append((f1, f2))
    rng.shuffle(positive_pairs)

    negative_pairs = []
    speakers = list(capped.keys())
    for f1, _ in positive_pairs:
        spk1 = next(s for s, files in capped.items() if f1 in files)
        other_speakers = [s for s in speakers if s != spk1]
        other_spk = rng.choice(other_speakers)
        other_file = rng.choice(capped[other_spk])
        negative_pairs.append((f1, other_file))

    eval_keys = list({f for pair in positive_pairs for f in pair} |
                     {f for pair in negative_pairs for f in pair})

    print(f"   -> {len(capped)} speakers used, {len(eval_keys)} unique files, "
          f"{len(positive_pairs)} positive / {len(negative_pairs)} negative pairs")

    return positive_pairs, negative_pairs, eval_keys


# =====================================================================
# DATASET LOADERS
# =====================================================================
def get_sinhala_trials(get_files_fn, num_speakers, utts_per_speaker, seed):
    print("-> Parsing local Sinhala dataset...")
    metadata = pd.read_csv(
        "utt_spk_text.tsv", sep="\t", header=None,
        names=["FileID", "UserID", "Transcription"],
    )

    local_files, paths = get_files_fn()
    available = metadata[metadata["FileID"].isin(local_files)]
    spk_to_files = available.groupby("UserID")["FileID"].apply(list).to_dict()

    print(f"   -> {len(spk_to_files)} total speakers available locally "
          f"(dataset has 478 speakers overall -- only locally downloaded ones are usable here)")

    positive_pairs, negative_pairs, eval_keys = build_balanced_trials(
        spk_to_files, num_speakers, utts_per_speaker, seed
    )

    def load_fn(f_id):
        path = paths[f_id]
        waveform, sr = torchaudio.load(path)
        if sr != 16000:
            waveform = torchaudio.transforms.Resample(sr, 16000)(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    return positive_pairs, negative_pairs, eval_keys, load_fn


def get_librispeech_trials(num_speakers, utts_per_speaker, seed):
    print("-> Loading LibriSpeech dev-clean dataset...")
    dataset = torchaudio.datasets.LIBRISPEECH(root="./", url="train-clean-100", download=True)

    idx_to_spk = {}
    for idx in range(len(dataset)):
        _, _, _, speaker_id, _, _ = dataset.get_metadata(idx)
        idx_to_spk[idx] = speaker_id

    spk_to_indices = {}
    for idx, spk in idx_to_spk.items():
        spk_to_indices.setdefault(spk, []).append(idx)

    positive_pairs, negative_pairs, eval_keys = build_balanced_trials(
        spk_to_indices, num_speakers, utts_per_speaker, seed
    )

    def load_fn(dataset_idx):
        waveform, sr, _, _, _, _ = dataset[dataset_idx]
        if sr != 16000:
            waveform = torchaudio.transforms.Resample(sr, 16000)(waveform)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
        return waveform.squeeze().numpy()

    return positive_pairs, negative_pairs, eval_keys, load_fn


# =====================================================================
# EVALUATOR
# =====================================================================
def evaluate_dataset(dataset_name, positive_pairs, negative_pairs, eval_keys,
                      load_fn, ecapa_model, xvect_model):
    print(f"\n--- Running verification on {dataset_name.upper()} ---")

    ecapa_cache, xvect_cache = {}, {}
    for idx, key in enumerate(eval_keys):
        if idx % 100 == 0 or idx == len(eval_keys) - 1:
            print(f"   -> Extracting embeddings: {idx + 1}/{len(eval_keys)}")
        try:
            audio_data = load_fn(key)
            ecapa_emb = get_embedding(audio_data, ecapa_model)
            xvect_emb = get_embedding(audio_data, xvect_model)
        except Exception as e:
            print(f"      [Warning] Skipping {key}: {e}")
            continue
        # Only cache if BOTH succeeded -- keeps the two caches in lockstep
        ecapa_cache[key] = ecapa_emb
        xvect_cache[key] = xvect_emb

    cos = torch.nn.CosineSimilarity(dim=-1)
    results = {}
    for model_name, cache in [("ECAPA-TDNN", ecapa_cache), ("X-Vector", xvect_cache)]:
        pos_scores = [cos(cache[a], cache[b]).item()
                      for a, b in positive_pairs if a in cache and b in cache]
        neg_scores = [cos(cache[a], cache[b]).item()
                      for a, b in negative_pairs if a in cache and b in cache]

        avg_pos = float(np.mean(pos_scores)) if pos_scores else 0.0
        avg_neg = float(np.mean(neg_scores)) if neg_scores else 0.0
        eer, thresh = calculate_eer(pos_scores, neg_scores)

        results[model_name] = {
            "avg_pos": avg_pos, "avg_neg": avg_neg,
            "margin": avg_pos - avg_neg, "thresh": thresh, "eer": eer,
            "n_pos": len(pos_scores), "n_neg": len(neg_scores),
        }
    return results


# =====================================================================
# MAIN
# =====================================================================
def main(get_files_fn):
    print("1. Loading models onto device...")
    ecapa_model = EncoderClassifier.from_hparams(
        source=ECAPA_SOURCE, savedir="tmpdir_ecapa", run_opts={"device": str(device)}
    )
    xvect_model = EncoderClassifier.from_hparams(
        source=XVECT_SOURCE, savedir="tmpdir_xvect", run_opts={"device": str(device)}
    )

    sinhala_pos, sinhala_neg, sinhala_eval, sinhala_load = get_sinhala_trials(
        get_files_fn, NUM_SPEAKERS_SINHALA, UTTS_PER_SPEAKER, RANDOM_SEED
    )
    english_pos, english_neg, english_eval, english_load = get_librispeech_trials(
        NUM_SPEAKERS_SINHALA, UTTS_PER_SPEAKER, RANDOM_SEED
    )

    sinhala_results = evaluate_dataset(
        "Sinhala", sinhala_pos, sinhala_neg, sinhala_eval, sinhala_load,
        ecapa_model, xvect_model,
    )
    english_results = evaluate_dataset(
        "English (LibriSpeech)", english_pos, english_neg, english_eval, english_load,
        ecapa_model, xvect_model,
    )

    print("\n" + "=" * 90)
    print("FINAL COMPARISON: ECAPA-TDNN vs X-VECTOR  (scaled, speaker-diversity aware)")
    print("=" * 90)

    rows = ["Average Same-Speaker Sim", "Average Diff-Speaker Sim",
            "Separation Margin (up=better)", "Decision Threshold",
            "Equal Error Rate (% down=better)", "N positive / N negative trials"]

    def col(res, model):
        r = res[model]
        return [
            f"{r['avg_pos']:.4f}", f"{r['avg_neg']:.4f}", f"{r['margin']:.4f}",
            f"{r['thresh']:.4f}", f"{r['eer']:.2f}%", f"{r['n_pos']} / {r['n_neg']}",
        ]

    summary = pd.DataFrame({
        "Metric": rows,
        "Sinhala: X-Vector": col(sinhala_results, "X-Vector"),
        "Sinhala: ECAPA": col(sinhala_results, "ECAPA-TDNN"),
        "English: X-Vector": col(english_results, "X-Vector"),
        "English: ECAPA": col(english_results, "ECAPA-TDNN"),
    })
    print(summary.to_string(index=False))
    print("=" * 90)
    return summary


if __name__ == "__main__":
    # Plug in your own get_files() here -- must return (local_file_ids, paths_dict)
    try:
        get_files  # noqa: F821 -- defined earlier in your notebook
    except NameError:
        raise RuntimeError(
            "get_files() is not defined. Define it (as in your original notebook) "
            "before running main(get_files)."
        )
    main(get_files)
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using symlink found at '/content/tmpdir_ecapa/hyperparams.yaml'
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using symlink found at '/content/tmpdir_ecapa/embedding_model.ckpt'
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using symlink found at '/content/tmpdir_ecapa/mean_var_norm_emb.ckpt'
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using symlink found at '/content/tmpdir_ecapa/classifier.ckpt'
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/tmpdir_ecapa/label_encoder.ckpt'
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# Running on device: CUDA
# 1. Loading models onto device...
# WARNING:speechbrain.inference.interfaces:Could not parse CUDA device string 'cuda': not enough values to unpack (expected 2, got 1). Falling back to device 0.
# ...

# %%
# !wget https://openslr.trmal.net/resources/28/rirs_noises.zip
# Out:
# --2026-07-15 12:45:07--  https://openslr.trmal.net/resources/28/rirs_noises.zip
# Resolving openslr.trmal.net (openslr.trmal.net)... 136.243.171.4, 2a01:4f8:171:2012::2
# Connecting to openslr.trmal.net (openslr.trmal.net)|136.243.171.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1311166223 (1.2G) [application/zip]
# Saving to: ‘rirs_noises.zip’
#
# rirs_noises.zip     100%[===================>]   1.22G  9.55MB/s    in 2m 44s
#
# 2026-07-15 12:47:52 (7.61 MB/s) - ‘rirs_noises.zip’ saved [1311166223/1311166223]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

shutil.copy("/content/asr_sinhala_0.zip", "/content/drive/MyDrive/Data_Science_Project/Datasets/zips")
shutil.copy("/content/asr_sinhala_1.zip", "/content/drive/MyDrive/Data_Science_Project/Datasets/zips")
shutil.copy("/content/asr_sinhala_2.zip", "/content/drive/MyDrive/Data_Science_Project/Datasets/zips")
shutil.copy("/content/rirs_noises.zip", "/content/drive/MyDrive/Data_Science_Project/Datasets/zips")
shutil.copy("/content/utt_spk_text.tsv", "/content/drive/MyDrive/Data_Science_Project/Datasets/zips")
# Out:
# '/content/drive/MyDrive/Data_Science_Project/Datasets/zips'
